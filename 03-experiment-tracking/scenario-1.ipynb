# %% [markdown]
# ## Scenario 1: A single data scientist participating in an ML competition
#
# This scenario demonstrates how an individual data scientist can use MLflow to track machine learning experiments on their local machine. This is a common setup for solo projects, hackathons, or competitions where collaboration and remote access are not required.
#
# ### MLflow setup overview
# - **Tracking server:** Not used (runs locally, no remote server)
# - **Backend store:** Local filesystem (stores experiment metadata in the `mlruns/` folder)
# - **Artifacts store:** Local filesystem (stores model files and other artifacts in the same `mlruns/` folder)
#
# With this setup, all experiment runs, parameters, metrics, and artifacts are saved locally. You can explore and compare your experiments using the MLflow UI.
#
# ### How to use the MLflow UI
# - You can launch the MLflow UI by running `mlflow ui` in your terminal, or by running the provided code cell in this notebook.
# - The UI will be available at [http://localhost:5000](http://localhost:5000).
# - Use the UI to browse experiments, compare runs, and inspect logged models and artifacts.
#
# > **Tip:** This local setup is ideal for learning and prototyping. For team projects or production, you would typically use a remote tracking server and a more robust backend (e.g., a database and cloud storage).

# %%
# %pip install mlflow
import mlflow
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting mlflow
#   Using cached mlflow-3.10.0-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-skinny==3.10.0 (from mlflow)
#   Using cached mlflow_skinny-3.10.0-py3-none-any.whl.metadata (32 kB)
# Collecting mlflow-tracing==3.10.0 (from mlflow)
#   Using cached mlflow_tracing-3.10.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Using cached flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting Flask<4 (from mlflow)
#   Using cached flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Using cached alembic-1.18.4-py3-none-any.whl.metadata (7.2 kB)
# Collecting cryptography<47,>=43.0.0 (from mlflow)
#   Using cached cryptography-46.0.5-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting huey<3,>=2.5.4 (from mlflow)
#   Using cached huey-2.6.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting matplotlib<4 (from mlflow)
#   Using cached matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Collecting numpy<3 (from mlflow)
#   Using cached numpy-2.4.2-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Collecting pandas<3 (from mlflow)
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting pyarrow<24,>=4.0.0 (from mlflow)
#   Using cached pyarrow-23.0.1-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting scikit-learn<2 (from mlflow)
#   Using cached scikit_learn-1.8.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting scipy<2 (from mlflow)
#   Using cached scipy-1.17.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting skops<1 (from mlflow)
#   Using cached skops-0.13.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Using cached sqlalchemy-2.0.48-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Collecting waitress<4 (from mlflow)
#   Using cached waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting cachetools<8,>=5.0.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached cachetools-7.0.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting click<9,>=7.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting cloudpickle<4 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached databricks_sdk-0.96.0-py3-none-any.whl.metadata (40 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached fastapi-0.135.1-py3-none-any.whl.metadata (30 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached gitpython-3.1.46-py3-none-any.whl.metadata (13 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached opentelemetry_proto-1.39.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<27 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from mlflow-skinny==3.10.0->mlflow) (26.0)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached protobuf-6.33.5-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting pydantic<3,>=2.0.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting python-dotenv<2,>=0.19.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting pyyaml<7,>=5.1 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Collecting requests<3,>=2.17.3 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting typing-extensions<5,>=4.0.0 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting uvicorn<1 (from mlflow-skinny==3.10.0->mlflow)
#   Using cached uvicorn-0.41.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting cffi>=2.0.0 (from cryptography<47,>=43.0.0->mlflow)
#   Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Collecting pywin32>=304 (from docker<8,>=4.0.0->mlflow)
#   Using cached pywin32-311-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Collecting urllib3>=1.26.0 (from docker<8,>=4.0.0->mlflow)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.1.2 (from Flask<4->mlflow)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe>=2.1.1 (from Flask<4->mlflow)
#   Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow)
#   Using cached werkzeug-3.1.6-py3-none-any.whl.metadata (4.0 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Collecting contourpy>=1.0.1 (from matplotlib<4->mlflow)
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib<4->mlflow)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4->mlflow)
#   Using cached fonttools-4.61.1-cp312-cp312-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<4->mlflow)
#   Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Collecting pillow>=8 (from matplotlib<4->mlflow)
#   Using cached pillow-12.1.1-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib<4->mlflow)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting pytz>=2020.1 (from pandas<3->mlflow)
#   Using cached pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3->mlflow)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting joblib>=1.3.0 (from scikit-learn<2->mlflow)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn<2->mlflow)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting prettytable>=3.9 (from skops<1->mlflow)
#   Using cached prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow)
#   Using cached greenlet-3.3.2-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow)
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: colorama in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.10.0->mlflow) (0.4.6)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.0->mlflow)
#   Using cached google_auth-2.48.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting starlette>=0.46.0 (from fastapi<1->mlflow-skinny==3.10.0->mlflow)
#   Using cached starlette-0.52.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting typing-inspection>=0.4.2 (from fastapi<1->mlflow-skinny==3.10.0->mlflow)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.10.0->mlflow)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==3.10.0->mlflow)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.10.0->mlflow)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting opentelemetry-semantic-conventions==0.60b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.10.0->mlflow)
#   Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wcwidth in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from prettytable>=3.9->skops<1->mlflow) (0.6.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2.0.0->mlflow-skinny==3.10.0->mlflow)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=2.0.0->mlflow-skinny==3.10.0->mlflow)
#   Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.17.3->mlflow-skinny==3.10.0->mlflow)
#   Using cached charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.17.3->mlflow-skinny==3.10.0->mlflow)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.17.3->mlflow-skinny==3.10.0->mlflow)
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting h11>=0.8 (from uvicorn<1->mlflow-skinny==3.10.0->mlflow)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.10.0->mlflow)
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.0->mlflow)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.0->mlflow)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting anyio<5,>=3.6.2 (from starlette>=0.46.0->fastapi<1->mlflow-skinny==3.10.0->mlflow)
#   Using cached anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.0->mlflow)
#   Using cached pyasn1-0.6.2-py3-none-any.whl.metadata (8.4 kB)
# Using cached mlflow-3.10.0-py3-none-any.whl (10.2 MB)
# Using cached mlflow_skinny-3.10.0-py3-none-any.whl (3.0 MB)
# Using cached mlflow_tracing-3.10.0-py3-none-any.whl (1.5 MB)
# Using cached alembic-1.18.4-py3-none-any.whl (263 kB)
# Using cached cryptography-46.0.5-cp311-abi3-win_amd64.whl (3.5 MB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached flask-3.1.3-py3-none-any.whl (103 kB)
# Using cached flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Using cached huey-2.6.0-py3-none-any.whl (76 kB)
# Using cached matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
# Downloading numpy-2.4.2-cp312-cp312-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.3 MB 1.1 MB/s eta 0:00:11
#    -- ------------------------------------- 0.8/12.3 MB 7.0 MB/s eta 0:00:02
#    ------- -------------------------------- 2.3/12.3 MB 14.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.2/12.3 MB 17.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.3/12.3 MB 20.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.9/12.3 MB 22.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.3 MB 24.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.8/12.3 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.3 MB 34.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 31.2 MB/s eta 0:00:00
# Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
# Using cached pyarrow-23.0.1-cp312-cp312-win_amd64.whl (27.6 MB)
# Using cached scikit_learn-1.8.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached scipy-1.17.1-cp312-cp312-win_amd64.whl (36.5 MB)
# Using cached skops-0.13.0-py3-none-any.whl (131 kB)
# Using cached sqlalchemy-2.0.48-cp312-cp312-win_amd64.whl (2.1 MB)
# Using cached waitress-3.0.2-py3-none-any.whl (56 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached cachetools-7.0.2-py3-none-any.whl (13 kB)
# Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached databricks_sdk-0.96.0-py3-none-any.whl (813 kB)
# Downloading fastapi-0.135.1-py3-none-any.whl (116 kB)
#    ---------------------------------------- 0.0/117.0 kB ? eta -:--:--
#    ---------------------------------------- 117.0/117.0 kB ? eta 0:00:00
# Using cached fonttools-4.61.1-cp312-cp312-win_amd64.whl (2.3 MB)
# Using cached gitpython-3.1.46-py3-none-any.whl (208 kB)
# Using cached graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached greenlet-3.3.2-cp312-cp312-win_amd64.whl (231 kB)
# Using cached importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl (15 kB)
# Using cached opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
# Using cached opentelemetry_proto-1.39.1-py3-none-any.whl (72 kB)
# Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
# Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
# Using cached pillow-12.1.1-cp312-cp312-win_amd64.whl (7.0 MB)
# Using cached prettytable-3.17.0-py3-none-any.whl (34 kB)
# Using cached protobuf-6.33.5-cp310-abi3-win_amd64.whl (437 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Using cached pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Using cached pywin32-311-cp312-cp312-win_amd64.whl (9.5 MB)
# Using cached pyyaml-6.0.3-cp312-cp312-win_amd64.whl (154 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached uvicorn-0.41.0-py3-none-any.whl (68 kB)
# Using cached werkzeug-3.1.6-py3-none-any.whl (225 kB)
# Using cached mako-1.3.10-py3-none-any.whl (78 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Using cached charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl (107 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached google_auth-2.48.0-py3-none-any.whl (236 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
#    ---------------------------------------- 0.0/74.3 kB ? eta -:--:--
#    ---------------------------------------- 74.3/74.3 kB ? eta 0:00:00
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Using cached anyio-4.12.1-py3-none-any.whl (113 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Using cached pyasn1-0.6.2-py3-none-any.whl (83 kB)
# Installing collected packages: pywin32, pytz, huey, zipp, waitress, urllib3, tzdata, typing-extensions, threadpoolctl, sqlparse, smmap, pyyaml, python-dotenv, pyparsing, pycparser, pyasn1, pyarrow, protobuf, prettytable, pillow, numpy, markupsafe, kiwisolver, joblib, itsdangerous, idna, h11, greenlet, graphql-core, fonttools, cycler, cloudpickle, click, charset_normalizer, certifi, cachetools, blinker, annotated-types, annotated-doc, werkzeug, uvicorn, typing-inspection, sqlalchemy, scipy, rsa, requests, pydantic-core, pyasn1-modules, pandas, opentelemetry-proto, Mako, jinja2, importlib_metadata, graphql-relay, gitdb, contourpy, cffi, anyio, starlette, scikit-learn, pydantic, opentelemetry-api, matplotlib, graphene, gitpython, Flask, docker, cryptography, alembic, skops, opentelemetry-semantic-conventions, google-auth, Flask-CORS, fastapi, opentelemetry-sdk, databricks-sdk, mlflow-tracing, mlflow-skinny, mlflow
# Successfully installed Flask-3.1.3 Flask-CORS-6.0.2 Mako-1.3.10 alembic-1.18.4 annotated-doc-0.0.4 annotated-types-0.7.0 anyio-4.12.1 blinker-1.9.0 cachetools-7.0.2 certifi-2026.2.25 cffi-2.0.0 charset_normalizer-3.4.4 click-8.3.1 cloudpickle-3.1.2 contourpy-1.3.3 cryptography-46.0.5 cycler-0.12.1 databricks-sdk-0.96.0 docker-7.1.0 fastapi-0.135.1 fonttools-4.61.1 gitdb-4.0.12 gitpython-3.1.46 google-auth-2.48.0 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 greenlet-3.3.2 h11-0.16.0 huey-2.6.0 idna-3.11 importlib_metadata-8.7.1 itsdangerous-2.2.0 jinja2-3.1.6 joblib-1.5.3 kiwisolver-1.4.9 markupsafe-3.0.3 matplotlib-3.10.8 mlflow-3.10.0 mlflow-skinny-3.10.0 mlflow-tracing-3.10.0 numpy-2.4.2 opentelemetry-api-1.39.1 opentelemetry-proto-1.39.1 opentelemetry-sdk-1.39.1 opentelemetry-semantic-conventions-0.60b1 pandas-2.3.3 pillow-12.1.1 prettytable-3.17.0 protobuf-6.33.5 pyarrow-23.0.1 pyasn1-0.6.2 pyasn1-modules-0.4.2 pycparser-3.0 pydantic-2.12.5 pydantic-core-2.41.5 pyparsing-3.3.2 python-dotenv-1.2.2 pytz-2026.1.post1 pywin32-311 pyyaml-6.0.3 requests-2.32.5 rsa-4.9.1 scikit-learn-1.8.0 scipy-1.17.1 skops-0.13.0 smmap-5.0.2 sqlalchemy-2.0.48 sqlparse-0.5.5 starlette-0.52.1 threadpoolctl-3.6.0 typing-extensions-4.15.0 typing-inspection-0.4.2 tzdata-2025.3 urllib3-2.6.3 uvicorn-0.41.0 waitress-3.0.2 werkzeug-3.1.6 zipp-3.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\zbook\downloads\ie-mlops-nyc-taxis\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'sqlite:///C:/Users/Zbook/Downloads/ie-mlops-nyc-taxis/03-experiment-tracking/mlflow.db'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///c:/Users/Zbook/Downloads/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/0', creation_time=1772556009246, experiment_id='0', last_update_time=1772556009246, lifecycle_stage='active', name='Default', tags={}, workspace='default'>]

# %% [markdown]
# ### Creating an experiment and logging a new run

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
import mlflow
import sklearn
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mlflow.set_experiment("my-experiment-1")

X, y = load_iris(return_X_y=True)
class_names = load_iris().target_names

models = [
    ("LogisticRegression", LogisticRegression(C=1.0, random_state=42, max_iter=1000, solver="lbfgs")),
    ("RandomForestClassifier", RandomForestClassifier(n_estimators=100, random_state=42))
]

for model_name, model in models:
    with mlflow.start_run() as run:
        mlflow.set_tag("model_type", model_name)
        mlflow.log_param("sklearn_version", sklearn.__version__)
        model.fit(X, y)
        y_pred = model.predict(X)
        acc = accuracy_score(y, y_pred)
        mlflow.log_metric("accuracy", acc)
        # Log confusion matrix as labeled DataFrame
        cm = confusion_matrix(y, y_pred)
        cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
        cm_df.to_csv("confusion_matrix_labeled.csv")
        mlflow.log_artifact("confusion_matrix_labeled.csv")
        # Confusion matrix heatmap as image
        plt.figure(figsize=(5,4))
        sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
        plt.title(f"Confusion Matrix ({model_name})")
        plt.ylabel("True label")
        plt.xlabel("Predicted label")
        plt.tight_layout()
        plt.savefig("confusion_matrix_heatmap.png")
        plt.close()
        mlflow.log_artifact("confusion_matrix_heatmap.png")
        # Provide input_example and use 'name' instead of deprecated 'artifact_path'
        input_example = np.expand_dims(X[0], axis=0)
        mlflow.sklearn.log_model(model, name="models", input_example=input_example)
        mlflow.set_tag("n_classes", len(np.unique(y)))
        mlflow.set_tag("run_time", datetime.datetime.now().isoformat())
        mlflow.set_tag("description", f"{model_name} on Iris dataset")
        print(f"Logged run for {model_name}, accuracy={acc:.3f}")
# Out:
# 2026/03/03 17:41:30 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# 2026/03/03 17:41:32 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Logged run for LogisticRegression, accuracy=0.973
# 2026/03/03 17:41:40 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Logged run for RandomForestClassifier, accuracy=1.000

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///c:/Users/Zbook/Downloads/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/1', creation_time=1772556090807, experiment_id='1', last_update_time=1772556090807, lifecycle_stage='active', name='my-experiment-1', tags={}, workspace='default'>,
#  <Experiment: artifact_location='file:///c:/Users/Zbook/Downloads/ie-mlops-nyc-taxis/03-experiment-tracking/mlruns/0', creation_time=1772556009246, experiment_id='0', last_update_time=1772556009246, lifecycle_stage='active', name='Default', tags={}, workspace='default'>]

# %%
# Launch MLflow UI (default: uses local mlruns/ folder)
import subprocess
import sys

# This will run 'mlflow ui' as a background process
subprocess.Popen([sys.executable, '-m', 'mlflow', 'ui'])
print("MLflow UI started. Open http://localhost:5000 in your browser.")
# Out:
# MLflow UI started. Open http://localhost:5000 in your browser.

# %% [markdown]
# ### Interacting with the model registry

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient()

# %%
from mlflow.exceptions import MlflowException

try:
    client.search_registered_models()
except MlflowException:
    print("It's not possible to access the model registry :(")
